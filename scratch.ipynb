# %%
import sys
sys.path.append("src")
from dagc.graphs import read_graph, generate_seed_set

G = read_graph("data/graphs/ba_1000_3.edgelist")
print(G.number_of_nodes(), G.number_of_edges())

seed_random = generate_seed_set(G, k=5, strategy="random")
seed_hd = generate_seed_set(G, k=5, strategy="high_degree")

print("Random seed set:", seed_random)
print("High-degree seed set:", seed_hd)
# Out:
# 1000 2991
# Random seed set: {96, 418, 758, 697, 926}
# High-degree seed set: {4, 5, 6, 7, 12}
