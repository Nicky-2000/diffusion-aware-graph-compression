# %%
import os
import sys
from pathlib import Path

import torch
import networkx as nx
import sys, os

ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(os.path.join(ROOT, "src"))

from dagc.data.graph_loading import load_graphs_from_dir, graph_to_tensors
from dagc.sparsifiers.gnn.train import load_gnn_sparsifier

# %%
ckpt_path = "results/checkpoints/gnn_rw_k1_keep0.8_num_steps_2.pt"
model = load_gnn_sparsifier(ckpt_path, device="cpu")
# Out:
# [load] Loaded GNNSparsifier from results/checkpoints/gnn_rw_k1_keep0.8_num_steps_2.pt on device cpu

# %%
from pathlib import Path

# Project root = parent of current working dir (or adjust as needed)
ROOT = Path.cwd().parent

split = "test" 

graph_dir = ROOT / "data" / "synthetic_graphs" / "ba" / split
print("Graph dir:", graph_dir)

graphs = load_graphs_from_dir(str(graph_dir))
graphs_10 = graphs[:10]
print("Loaded", len(graphs_10), "graphs for evaluation")
# Out:
# Graph dir: /Users/nicholaskhorasani/Documents/CodingProjects/diffusion-aware-graph-compression/data/synthetic_graphs/ba/test
# Loaded 10 graphs for evaluation

# %%
from dagc.metrics.collect_metrics import evaluate_one_graph

# %%
keep_ratio = 0.5
seed_set_size = 10
activation_prob = 0.1
num_runs = 200

all_rand = []
all_gnn = []
all_eff = []

for idx, G in enumerate(graphs_10):
    print(f"\n================  Graph {idx}  ================")
    print(f"|V| = {G.number_of_nodes()}, |E| = {G.number_of_edges()}")

    (
        metrics_rand,
        metrics_gnn,
        metrics_eff,
        orig_summary,
        rand_summary,
        gnn_summary,
        eff_summary,
        H_rand,
        H_gnn,
        H_eff,
    ) = evaluate_one_graph(
        G=G,
        model=model,
        keep_ratio=keep_ratio,
        seed_set_size=seed_set_size,
        activation_prob=activation_prob,
        num_runs=num_runs,
        base_seed=12345 + idx * 10000,  # different seed per graph
        device="cpu",
    )

    all_rand.append(metrics_rand)
    all_gnn.append(metrics_gnn)
    all_eff.append(metrics_eff)

    # Edge counts
    print(f"|E_rand| = {H_rand.number_of_edges()} (random sparsifier)")
    print(f"|E_gnn|  = {H_gnn.number_of_edges()} (GNN sparsifier)")
    print(f"|E_eff|  = {H_eff.number_of_edges()} (ER sparsifier)")

    # Raw expected spreads
    orig_spread = orig_summary.expected_spread
    rand_spread = rand_summary.expected_spread
    gnn_spread = gnn_summary.expected_spread
    eff_spread = eff_summary.expected_spread

    print("\nRaw expected spreads:")
    print(f"  Original:       {orig_spread:.3f}")
    print(f"  Random sparse:  {rand_spread:.3f}")
    print(f"  GNN sparse:     {gnn_spread:.3f}")
    print(f"  ER sparse:      {eff_spread:.3f}")

    # Simple diffusion-preservation metrics
    print("\nRandom sparsifier vs original:")
    print(f"  spread_abs_diff:  {metrics_rand['spread_abs_diff']:.3f}")
    print(f"  prob_mse:         {metrics_rand['prob_mse']:.6f}")

    print("\nGNN sparsifier vs original:")
    print(f"  spread_abs_diff:  {metrics_gnn['spread_abs_diff']:.3f}")
    print(f"  prob_mse:         {metrics_gnn['prob_mse']:.6f}")

    print("\nEffective-resistance sparsifier vs original:")
    print(f"  spread_abs_diff:  {metrics_eff['spread_abs_diff']:.3f}")
    print(f"  prob_mse:         {metrics_eff['prob_mse']:.6f}")
# Out:
# ================  Graph 0  ================
# |V| = 1000, |E| = 2991
# Shifting edge scores by 0.0000 to ensure non-negativity.
# |E_rand| = 1496 (random sparsifier)
# |E_gnn|  = 1495 (GNN sparsifier)
# |E_eff|  = 1166 (ER sparsifier)
#
# Raw expected spreads:
#   Original:       129.765
#   Random sparse:  47.955
#   GNN sparse:     95.935
#   ER sparse:      100.190
#
# Random sparsifier vs original:
#   spread_abs_diff:  81.810
#   prob_mse:         0.010671
#
# GNN sparsifier vs original:
#   spread_abs_diff:  33.830
#   prob_mse:         0.002434
#
# Effective-resistance sparsifier vs original:
#   spread_abs_diff:  29.575
#   prob_mse:         0.014937
#
# ================  Graph 1  ================
# |V| = 1000, |E| = 2991
# Shifting edge scores by 0.0000 to ensure non-negativity.
# |E_rand| = 1496 (random sparsifier)
# |E_gnn|  = 1495 (GNN sparsifier)
# |E_eff|  = 1165 (ER sparsifier)
#
# Raw expected spreads:
#   Original:       132.035
#   Random sparse:  50.145
#   GNN sparse:     97.750
#   ER sparse:      97.445
#
# Random sparsifier vs original:
#   spread_abs_diff:  81.890
#   prob_mse:         0.010586
#
# GNN sparsifier vs original:
#   spread_abs_diff:  34.285
#   prob_mse:         0.002454
#
# Effective-resistance sparsifier vs original:
#   spread_abs_diff:  34.590
#   prob_mse:         0.013706
#
# ================  Graph 2  ================
# |V| = 1000, |E| = 2991
# Shifting edge scores by 0.0000 to ensure non-negativity.
# |E_rand| = 1496 (random sparsifier)
# |E_gnn|  = 1495 (GNN sparsifier)
# |E_eff|  = 1145 (ER sparsifier)
#
# Raw expected spreads:
#   Original:       122.410
#   Random sparse:  43.510
#   GNN sparse:     91.025
#   ER sparse:      96.910
#
# Random sparsifier vs original:
#   spread_abs_diff:  78.900
#   prob_mse:         0.010413
#
# GNN sparsifier vs original:
#   spread_abs_diff:  31.385
#   prob_mse:         0.002197
#
# Effective-resistance sparsifier vs original:
#   spread_abs_diff:  25.500
#   prob_mse:         0.013920
#
# ================  Graph 3  ================
# |V| = 1000, |E| = 2991
# Shifting edge scores by 0.0000 to ensure non-negativity.
# |E_rand| = 1496 (random sparsifier)
# |E_gnn|  = 1495 (GNN sparsifier)
# |E_eff|  = 1159 (ER sparsifier)
#
# Raw expected spreads:
#   Original:       125.450
#   Random sparse:  45.940
#   GNN sparse:     94.945
#   ER sparse:      93.615
#
# Random sparsifier vs original:
#   spread_abs_diff:  79.510
#   prob_mse:         0.010550
#
# GNN sparsifier vs original:
#   spread_abs_diff:  30.505
#   prob_mse:         0.002128
#
# Effective-resistance sparsifier vs original:
#   spread_abs_diff:  31.835
#   prob_mse:         0.013443
#
# ================  Graph 4  ================
# |V| = 1000, |E| = 2991
# Shifting edge scores by 0.0000 to ensure non-negativity.
# |E_rand| = 1496 (random sparsifier)
# |E_gnn|  = 1495 (GNN sparsifier)
# |E_eff|  = 1165 (ER sparsifier)
#
# Raw expected spreads:
#   Original:       126.320
#   Random sparse:  45.810
#   GNN sparse:     90.390
#   ER sparse:      101.830
#
# Random sparsifier vs original:
#   spread_abs_diff:  80.510
#   prob_mse:         0.010678
#
# GNN sparsifier vs original:
#   spread_abs_diff:  35.930
#   prob_mse:         0.002621
#
# Effective-resistance sparsifier vs original:
#   spread_abs_diff:  24.490
#   prob_mse:         0.015762
#
# ================  Graph 5  ================
# |V| = 1000, |E| = 2991
# Shifting edge scores by 0.0000 to ensure non-negativity.
# |E_rand| = 1496 (random sparsifier)
# |E_gnn|  = 1495 (GNN sparsifier)
# |E_eff|  = 1142 (ER sparsifier)
#
# Raw expected spreads:
#   Original:       126.660
#   Random sparse:  47.765
#   GNN sparse:     94.205
#   ER sparse:      101.085
#
# Random sparsifier vs original:
#   spread_abs_diff:  78.895
#   prob_mse:         0.010207
#
# GNN sparsifier vs original:
#   spread_abs_diff:  32.455
#   prob_mse:         0.002402
#
# Effective-resistance sparsifier vs original:
#   spread_abs_diff:  25.575
#   prob_mse:         0.014216
#
# ================  Graph 6  ================
# |V| = 1000, |E| = 2991
# Shifting edge scores by 0.0000 to ensure non-negativity.
# |E_rand| = 1496 (random sparsifier)
# |E_gnn|  = 1495 (GNN sparsifier)
# |E_eff|  = 1145 (ER sparsifier)
#
# Raw expected spreads:
#   Original:       114.440
#   Random sparse:  41.750
#   GNN sparse:     82.265
#   ER sparse:      97.095
#
# Random sparsifier vs original:
#   spread_abs_diff:  72.690
#   prob_mse:         0.008924
#
# GNN sparsifier vs original:
#   spread_abs_diff:  32.175
#   prob_mse:         0.002105
#
# Effective-resistance sparsifier vs original:
#   spread_abs_diff:  17.345
#   prob_mse:         0.014448
#
# ================  Graph 7  ================
# |V| = 1000, |E| = 2991
# Shifting edge scores by 0.0000 to ensure non-negativity.
# |E_rand| = 1496 (random sparsifier)
# |E_gnn|  = 1495 (GNN sparsifier)
# |E_eff|  = 1156 (ER sparsifier)
#
# Raw expected spreads:
#   Original:       129.855
#   Random sparse:  48.660
#   GNN sparse:     92.655
#   ER sparse:      103.790
#
# Random sparsifier vs original:
#   spread_abs_diff:  81.195
#   prob_mse:         0.010472
#
# GNN sparsifier vs original:
#   spread_abs_diff:  37.200
#   prob_mse:         0.002555
#
# Effective-resistance sparsifier vs original:
#   spread_abs_diff:  26.065
#   prob_mse:         0.015872
#
# ================  Graph 8  ================
# |V| = 1000, |E| = 2991
# Shifting edge scores by 0.0000 to ensure non-negativity.
# |E_rand| = 1496 (random sparsifier)
# |E_gnn|  = 1495 (GNN sparsifier)
# |E_eff|  = 1161 (ER sparsifier)
#
# Raw expected spreads:
#   Original:       120.480
#   Random sparse:  46.865
#   GNN sparse:     89.625
#   ER sparse:      92.400
#
# Random sparsifier vs original:
#   spread_abs_diff:  73.615
#   prob_mse:         0.009219
#
# GNN sparsifier vs original:
#   spread_abs_diff:  30.855
#   prob_mse:         0.002121
#
# Effective-resistance sparsifier vs original:
#   spread_abs_diff:  28.080
#   prob_mse:         0.012845
#
# ================  Graph 9  ================
# |V| = 1000, |E| = 2991
# Shifting edge scores by 0.0000 to ensure non-negativity.
# |E_rand| = 1496 (random sparsifier)
# |E_gnn|  = 1495 (GNN sparsifier)
# |E_eff|  = 1142 (ER sparsifier)
#
# Raw expected spreads:
#   Original:       127.425
#   Random sparse:  47.905
#   GNN sparse:     93.840
#   ER sparse:      100.115
#
# Random sparsifier vs original:
#   spread_abs_diff:  79.520
#   prob_mse:         0.010113
#
# GNN sparsifier vs original:
#   spread_abs_diff:  33.585
#   prob_mse:         0.002324
#
# Effective-resistance sparsifier vs original:
#   spread_abs_diff:  27.310
#   prob_mse:         0.015834

# %%
import pandas as pd

rows = []

for idx, (m_r, m_g, m_e) in enumerate(zip(all_rand, all_gnn, all_eff)):
    rows.append({
        "graph_idx": idx,
        "method": "random",
        "spread_abs_diff": m_r["spread_abs_diff"],
        "prob_mse": m_r["prob_mse"],
    })
    rows.append({
        "graph_idx": idx,
        "method": "gnn",
        "spread_abs_diff": m_g["spread_abs_diff"],
        "prob_mse": m_g["prob_mse"],
    })
    rows.append({
        "graph_idx": idx,
        "method": "er",
        "spread_abs_diff": m_e["spread_abs_diff"],
        "prob_mse": m_e["prob_mse"],
    })

df = pd.DataFrame(rows)
print(df.head())
# Out:
#    graph_idx  method  spread_abs_diff  prob_mse
# 0          0  random           81.810  0.010671
# 1          0     gnn           33.830  0.002434
# 2          0      er           29.575  0.014937
# 3          1  random           81.890  0.010586
# 4          1     gnn           34.285  0.002454

# %%
summary = df.groupby("method").agg(
    mean_spread_abs_diff=("spread_abs_diff", "mean"),
    std_spread_abs_diff=("spread_abs_diff", "std"),
    mean_prob_mse=("prob_mse", "mean"),
    std_prob_mse=("prob_mse", "std"),
).reset_index()

print(summary)
# Out:
#    method  mean_spread_abs_diff  std_spread_abs_diff  mean_prob_mse  \
# 0      er               27.0365             4.637278       0.014498
# 1     gnn               33.2205             2.181563       0.002334
# 2  random               78.8535             3.205855       0.010183
#
#    std_prob_mse
# 0      0.001072
# 1      0.000188
# 2      0.000618

# %%
import matplotlib.pyplot as plt

methods = ["random", "gnn", "er"]

# Spread diff
plt.figure()
means = [summary.loc[summary.method == m, "mean_spread_abs_diff"].item() for m in methods]
stds  = [summary.loc[summary.method == m, "std_spread_abs_diff"].item()  for m in methods]
plt.bar(methods, means, yerr=stds)
plt.ylabel("|E[spread(G)] - E[spread(G')]|")
plt.title("Global diffusion error (Expected spread diff)")
plt.tight_layout()
plt.show()

# Prob MSE
plt.figure()
means = [summary.loc[summary.method == m, "mean_prob_mse"].item() for m in methods]
stds  = [summary.loc[summary.method == m, "std_prob_mse"].item()  for m in methods]
plt.bar(methods, means, yerr=stds)
plt.ylabel("MSE over per-node activation probabilities")
plt.title("Local diffusion error (activation prob MSE)")
plt.tight_layout()
plt.show()
